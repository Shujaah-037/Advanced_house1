# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 = pd.read_csv("/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/train.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test = pd.read_csv("/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/test.csv")

# %%
subm = pd.read_csv("/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/sample_submission.csv")

# %%
data1.shape
# Out:
# (1460, 81)

# %% [markdown]
# Convert categorical data into numeric data

# %%
data1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train = pd.get_dummies(data1)
test = pd.get_dummies(test)

# %%
len(train.columns)
# Out:
# 290

# %%
len(test.columns)
# Out:
# 271

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 290 entries, Id to SaleCondition_Partial
# dtypes: float64(3), int64(35), uint8(252)
# memory usage: 792.9 KB

# %%
dependent_variable = train.SalePrice

# %%
dependent_variable
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
da = data1["SalePrice"]

# %%
da
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# To have the same columns of train data, as test data

# %%
train = train[test.columns]
train['SalePrice'] = dependent_variable
# Out:
# <ipython-input-16-1d6d91c80f52>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['SalePrice'] = dependent_variable

# %%
len(train.columns)
# Out:
# 272

# %%
len(test.columns)
# Out:
# 271

# %%
train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_New  \
# ...

# %%
train = train.set_index("Id")

# %%
test = test.set_index("Id")

# %%
train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
# ...

# %%
condition = (train.corr() < -0.7) | (train.corr() > 0.7) & (train.corr() != 1)
correlation = train.drop('SalePrice', axis=1).corr()[condition].dropna(how='all', axis=0)
collinearity = correlation[correlation.index]

# %%
collinearity
# Out:
#                        MSSubClass  YearBuilt  BsmtFinSF2  TotalBsmtSF  \
# MSSubClass                    NaN        NaN         NaN          NaN
# YearBuilt                     NaN        NaN         NaN          NaN
# BsmtFinSF2                    NaN        NaN         NaN          NaN
# TotalBsmtSF                   NaN        NaN         NaN          NaN
# 1stFlrSF                      NaN        NaN         NaN      0.81953
# ...                           ...        ...         ...          ...
# PavedDrive_Y                  NaN        NaN         NaN          NaN
# MiscFeature_Gar2              NaN        NaN         NaN          NaN
# SaleType_New                  NaN        NaN         NaN          NaN
# SaleType_WD                   NaN        NaN         NaN          NaN
# SaleCondition_Partial         NaN        NaN         NaN          NaN
#
#                        1stFlrSF  2ndFlrSF  GrLivArea  TotRmsAbvGrd  \
# ...

# %%
x = list(collinearity.columns)
for i in x:
    x.remove(collinearity[i].dropna().index[0])
x
# Out:
# ['MSSubClass',
#  'YearBuilt',
#  'BsmtFinSF2',
#  'TotalBsmtSF',
#  'GrLivArea',
#  'GarageCars',
#  'MiscVal',
#  'MSZoning_FV',
#  'MSZoning_RL',
#  'Street_Grvl',
#  'LotShape_IR1',
#  'LotConfig_Corner',
#  'LandSlope_Gtl',
#  'HouseStyle_2Story',
#  'RoofStyle_Gable',
#  'RoofMatl_Tar&Grv',
#  'Exterior1st_CemntBd',
#  'Exterior1st_HdBoard',
#  'Exterior1st_MetalSd',
#  'Exterior1st_Plywood',
#  'Exterior1st_Stucco',
#  'Exterior1st_VinylSd',
#  'Exterior1st_Wd Sdng',
#  'Exterior2nd_AsbShng',
#  'MasVnrType_None',
#  'ExterQual_TA',
#  'ExterCond_TA',
#  'Foundation_PConc',
#  'BsmtQual_TA',
#  'Heating_GasW',
#  'CentralAir_Y',
#  'Electrical_SBrkr',
#  'KitchenQual_TA',
#  'GarageType_Detchd',
#  'GarageCond_TA',
#  'PavedDrive_Y',
#  'SaleType_WD',
#  'SaleCondition_Partial']

# %%
collinearity[train[x].corr()[condition].isnull() == False].dropna(how='all')
# Out:
#                        MSSubClass  YearBuilt  BsmtFinSF2  TotalBsmtSF  \
# SaleType_WD                   NaN        NaN         NaN          NaN
# SaleCondition_Partial         NaN        NaN         NaN          NaN
#
#                        1stFlrSF  2ndFlrSF  GrLivArea  TotRmsAbvGrd  \
# SaleType_WD                 NaN       NaN        NaN           NaN
# SaleCondition_Partial       NaN       NaN        NaN           NaN
#
#                        GarageYrBlt  GarageCars  ...  GarageType_Attchd  \
# SaleType_WD                    NaN         NaN  ...                NaN
# SaleCondition_Partial          NaN         NaN  ...                NaN
#
#                        GarageType_Detchd  GarageQual_TA  GarageCond_TA  \
# SaleType_WD                          NaN            NaN            NaN
# SaleCondition_Partial                NaN            NaN            NaN
#
#                        PavedDrive_N  PavedDrive_Y  MiscFeature_Gar2  \
# ...

# %%
x.remove('SaleType_WD')

# %%
train = train.drop(x, axis=1)
test = test.drop(x, axis=1)

# %%
(train.isnull().sum() / train.shape[0])[train.columns[train.isnull().sum() > 0]]
# Out:
# LotFrontage    0.177397
# MasVnrArea     0.005479
# GarageYrBlt    0.055479
# dtype: float64

# %%
train = train.drop(['LotFrontage', 'GarageYrBlt'], axis=1)
test = test.drop(['LotFrontage', 'GarageYrBlt'], axis=1)

# %%
train[train.MasVnrArea.isnull() == True]
# Out:
#       LotArea  OverallQual  OverallCond  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 235      7851            6            5          2002         NaN         625
# 530     32668            6            3          1975         NaN        1219
# 651      8125            7            6          2007         NaN           0
# 937     10083            7            5          2003         NaN         833
# 974     11639            7            5          2008         NaN           0
# 978      4274            7            5          2007         NaN        1106
# 1244    13891           10            5          2006         NaN        1386
# 1279     9473            8            5          2002         NaN         804
#
#       BsmtUnfSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  SaleType_ConLw  \
# Id                                                 ...
# 235         235       860      1100             0  ...               0
# ...

# %%
train = train.drop(train[train.MasVnrArea.isnull() == True].index)

# %%
(test.isnull().sum() / test.shape[0])[test.columns[test.isnull().sum() > 0]]
# Out:
# MasVnrArea      0.010281
# BsmtFinSF1      0.000685
# BsmtUnfSF       0.000685
# BsmtFullBath    0.001371
# BsmtHalfBath    0.001371
# GarageArea      0.000685
# dtype: float64

# %%
null_columns = list((test.isnull().sum() / test.shape[0])[test.columns[test.isnull().sum() > 0]].index)

# %%
train.corr()['SalePrice'][null_columns]
# Out:
# MasVnrArea      0.477493
# BsmtFinSF1      0.383977
# BsmtUnfSF       0.215740
# BsmtFullBath    0.225027
# BsmtHalfBath   -0.015993
# GarageArea      0.622492
# Name: SalePrice, dtype: float64

# %%
train = train.drop(['MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'BsmtFullBath', 'BsmtHalfBath'], axis=1)
test = test.drop(['MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'BsmtFullBath', 'BsmtHalfBath'], axis=1)

# %%
test[test.GarageArea.isnull() == True]
# Out:
#       LotArea  OverallQual  OverallCond  YearRemodAdd  1stFlrSF  2ndFlrSF  \
# Id
# 2577     9060            5            6          1999       942       886
#
#       LowQualFinSF  FullBath  HalfBath  BedroomAbvGr  ...  SaleType_ConLI  \
# Id                                                    ...
# 2577             0         2         0             3  ...               0
#
#       SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# Id
# 2577               0             0             0            1
#
#       SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# Id
# 2577                      0                      0                     1
#
#       SaleCondition_Family  SaleCondition_Normal
# Id
# 2577                     0                     0
#
# [1 rows x 226 columns]

# %%
test.GarageArea = test.GarageArea.fillna(round(test.GarageArea.mean(),0))

# %%
X = train.drop('SalePrice', axis=1)
y = train.SalePrice

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X[:] = scaler.fit_transform(X)
test[:] = scaler.fit_transform(test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, random_state=2023)
X_test = test

# %%
from sklearn.linear_model import Lasso

# %% [markdown]
# ## Solving or reducing error that Input contains NaN, infinity or a value too large for dtype('float64')

# %%
import pandas as pd
import numpy as np
df = X_train
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
import pandas as pd
import numpy as np
df1 = y_train
def clean_dataset(df1):
    assert isinstance(df1, pd.DataFrame), "df1 needs to be a pd.DataFrame"
    df1.dropna(inplace=True)
    indices_to_keep = ~df1.isin([np.nan, np.inf, -np.inf]).any(1)
    return df1[indices_to_keep].astype(np.float64)

# %%
np.where(X_train.values >= np.finfo(np.float64).max)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
np.where(y_train.values >= np.finfo(np.float64).max)
# Out:
# (array([], dtype=int64),)

# %%
df1
# Out:
# Id
# 480      89471
# 1260    151000
# 1272    185750
# 16      132000
# 720     128500
#          ...
# 888     135500
# 517     158000
# 699     138500
# 456     175500
# 859     152000
# Name: SalePrice, Length: 1161, dtype: int64

# %%
# remove rows that contain NaN values
df = df.dropna()

# remove rows that contain inf or -inf values
df = df[~(df == np.inf).any(1)]
df = df[~(df == -np.inf).any(1)]
# Out:
# <ipython-input-48-c50267c7b6f0>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df = df[~(df == np.inf).any(1)]
# <ipython-input-48-c50267c7b6f0>:6: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df = df[~(df == -np.inf).any(1)]

# %%
# replace NaN values with the mean of the column
df = df.fillna(df.mean())

# replace inf or -inf values with a specific value
df[df == np.inf] = 99999
df[df == -np.inf] = -99999

# %%
from sklearn.linear_model import Ridge

# %%
import numpy as np
df = df.replace([np.inf, -np.inf], np.nan)
df = df.fillna(0)

# %%
y_val
# Out:
# Id
# 799     485000
# 1291    180500
# 1184    120000
# 683     173000
# 1035    119750
#          ...
# 371     172400
# 755     156000
# 1205    153500
# 1331    227000
# 155     125000
# Name: SalePrice, Length: 291, dtype: int64

# %% [markdown]
# ## Ridge Regression

# %%
r = Ridge(alpha=100)
r.fit(df, df1)
y_pred_train_r = r.predict(X_train)
y_pred_val_r = r.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error
import math

# %%
print('Ridge Regression:', math.sqrt(mean_squared_error(y_val, y_pred_val_r)))
# Out:
# Ridge Regression: 38361.607376978085

# %%
test = test.drop("id", axis =1)

# %%
subm['SalePrice'] = r.predict(test)
subm.to_csv('/content/drive/MyDrive/Kaggle_1/playground-series-s3e1/shuja_jan_ep1_sub.csv',index=False)

# %%
import numpy as np
y_pred_test_r = r.predict(X_test)
output = pd.DataFrame({'Id': X_test.index, 'SalePrice': np.round(y_pred_test_r, 0)})
output.to_csv('/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/submission.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/submission.csv')

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=500, max_features=int(len(train.columns)*0.7))
rfr.fit(X_train, y_train)
y_pred_train_rfr = rfr.predict(X_train)
y_pred_val_rfr = rfr.predict(X_val)

# %%
print('Random Forest Regression:', math.sqrt(mean_squared_error(y_train, y_pred_train_rfr)))
# Out:
# Random Forest Regression: 11027.998804425937

# %%
import numpy as np
y_pred_test_rfr = rfr.predict(X_test)
output = pd.DataFrame({'Id': X_test.index, 'SalePrice': np.round(y_pred_test_rfr, 0)})
output.to_csv('/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/submissionFor.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/Kaggle_1/house-prices-advanced-regression-techniques/submissionFor.csv')
# Out:
#         Id  SalePrice
# 0     1461   137452.0
# 1     1462   153844.0
# 2     1463   167463.0
# 3     1464   182030.0
# 4     1465   197625.0
# ...    ...        ...
# 1454  2915    86112.0
# 1455  2916    86654.0
# 1456  2917   163684.0
# 1457  2918   112063.0
# 1458  2919   232193.0
#
# [1459 rows x 2 columns]

# %% [markdown]
#  #Xgboost

# %%
import xgboost as xgb
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %%
model_xgb = xgb.XGBRegressor()

# %%
n_folds = 13

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=1).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %%
model_xgb.fit(X_train,y_train)
# Out:
# [10:04:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
subm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1459 non-null   int64
#  1   SalePrice  1459 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 22.9 KB

# %%
predi = model_xgb.predict(test)

# %%
predi.shape
# Out:
# (1459,)

# %%
subm.shape
# Out:
# (1459, 2)

# %%
subm['SalePrice'] = predi
subm.to_csv('/content/drive/MyDrive/Kaggle_1/playground-series-s3e1/xgboost.csv',index=False)
